# %%
import pandas as pd
df =pd.read_csv('out.csv')
df.head()
Day = df['Day']
Time = df['Time']
Freq = df['Freq']
PCT = df['PCT']

for i in xrange(7):
    for j in xrange(4)
        # (i, j): [
        for k in xrange(616):
            if Day[k] == i && Time[k] == j
                #( Freq[k], PCT[k]),
        #

# %%
import pandas as pd
df =pd.read_csv('out.csv')
df.head()
Day = df['Day']
Time = df['Time']
Freq = df['Freq']
PCT = df['PCT']

print Freq, PCT

# %%
import pandas as pd
import numpy
df =pd.read_csv('out.csv')
df.head()
Day = df['Day']
Time = df['Time']
Freq = df['Freq']
PCT = df['PCT']

Dict = {}

crimes = numpy.zeros((7,4))

for i in xrange(7):
    for j in xrange(4):
        print '(',i,',', j,'): ['
        num = 0;
        for k in xrange(22):
            num += Freq[i*4*22+j*22+k]
            if k != 21:
                print '(',Freq[i*4*22+j*22+k], ',', PCT[i*4*22+j*22+k], '),' 
            if k == 21:
                print '(',Freq[i*4*22+j*22+k], ',', PCT[i*4*22+j*22+k], ')],' 
        crimes[i,j] = num
print '}'

print crimes
# Out:
# ( 0 , 0 ): [
# ( 0.344444444 , 1 ),
# ( 0.262962963 , 5 ),
# ( 0.406481481 , 6 ),
# ( 0.271296296 , 7 ),
# ( 0.314814815 , 9 ),
# ( 0.332407407 , 10 ),
# ( 0.387962963 , 13 ),
# ( 0.446296296 , 14 ),
# ( 0.237037037 , 17 ),
# ( 0.361111111 , 18 ),
# ( 0.271296296 , 19 ),
# ( 0.327777778 , 20 ),
# ( 0.010185185 , 22 ),
# ( 0.446296296 , 23 ),
# ( 0.413888889 , 24 ),
# ( 0.324074074 , 25 ),
# ( 0.17037037 , 26 ),
# ( 0.262037037 , 28 ),
# ( 0.291666667 , 30 ),
# ( 0.375 , 32 ),
# ( 0.37037037 , 33 ),
# ( 0.776851852 , 34 )],
# ( 0 , 1 ): [
# ( 0.800925926 , 1 ),
# ( 0.437962963 , 5 ),
# ( 0.439814815 , 6 ),
# ( 0.422222222 , 7 ),
# ( 0.425 , 9 ),
# ( 0.427777778 , 10 ),
# ( 0.946296296 , 13 ),
# ( 1.126851852 , 14 ),
# ( 0.387962963 , 17 ),
# ( 0.77037037 , 18 ),
# ( 0.787037037 , 19 ),
# ( 0.537037037 , 20 ),
# ( 0.039814815 , 22 ),
# ( 0.768518519 , 23 ),
# ( 0.606481481 , 24 ),
# ( 0.684259259 , 25 ),
# ( 0.349074074 , 26 ),
# ( 0.501851852 , 28 ),
# ( 0.409259259 , 30 ),
# ...

# %%
# %matplotlib inline

import matplotlib.pyplot as plt

x = [1,2,3,4,5,6,7]


plt.plot(x, crimes[:,0],'ko',label="Night")
plt.plot(x, crimes[:,0],'k-')
plt.plot(x, crimes[:,1],'bo',label="Morning")
plt.plot(x, crimes[:,1],'b-')
plt.plot(x, crimes[:,2],'go',label="Afternoon")
plt.plot(x, crimes[:,2],'g-')
plt.plot(x, crimes[:,3],'ro',label="Evening")
plt.plot(x, crimes[:,3],'r-')
plt.xlabel("Weekday")
plt.ylabel("Number of Crimes")
plt.title("The Number of Crimes under Different Day and Time")
plt.legend(bbox_to_anchor=(1.4, 1.05))

# %%
x = [1,2,3,4,5,6,7]
