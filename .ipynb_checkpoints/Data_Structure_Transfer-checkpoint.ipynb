# %%
import pandas as pd
df =pd.read_csv('out.csv')
df.head()
Day = df['Day']
Time = df['Time']
Freq = df['Freq']
PCT = df['PCT']

for i in xrange(7):
    for j in xrange(4)
        # (i, j): [
        for k in xrange(616):
            if Day[k] == i && Time[k] == j
                #( Freq[k], PCT[k]),
        #

# %%
import pandas as pd
df =pd.read_csv('out.csv')
df.head()
Day = df['Day']
Time = df['Time']
Freq = df['Freq']
PCT = df['PCT']

print Freq, PCT
# Out:
# 0      0.344444
# 1      0.262963
# 2      0.406481
# 3      0.271296
# 4      0.314815
# 5      0.332407
# 6      0.387963
# 7      0.446296
# 8      0.237037
# 9      0.361111
# 10     0.271296
# 11     0.327778
# 12     0.010185
# 13     0.446296
# 14     0.413889
# 15     0.324074
# 16     0.170370
# 17     0.262037
# 18     0.291667
# 19     0.375000
# 20     0.370370
# 21     0.776852
# 22     0.800926
# 23     0.437963
# 24     0.439815
# 25     0.422222
# 26     0.425000
# 27     0.427778
# 28     0.946296
# 29     1.126852
#          ...
# 586    0.899074
# 587    0.962037
# 588    0.431481
# 589    0.955556
# 590    0.732407
# 591    0.967593
# 592    0.508333
# 593    0.751852
# 594    0.781481
# 595    0.465741
# 596    0.604630
# 597    0.650000
# 598    0.845370
# 599    0.480556
# 600    0.946296
# 601    1.608333
# 602    0.467593
# 603    0.919444
# 604    0.652778
# 605    0.536111
# 606    0.010185
# 607    1.164815
# 608    0.690741
# 609    0.937963
# ...

# %%
import pandas as pd
df =pd.read_csv('out.csv')
df.head()
Day = df['Day']
Time = df['Time']
Freq = df['Freq']
PCT = df['PCT']

Dict = {}

for i in xrange(7):
    for j in xrange(4):
        print '(',i,',', j,'): ['
        for k in xrange(22):
            if k != 21:
                print '(',Freq[i*4*22+j*22+k], ',', PCT[i*4*22+j*22+k], '),' 
            if k == 21:
                print '(',Freq[i*4*22+j*22+k], ',', PCT[i*4*22+j*22+k], ')],' 
print '}'
        
                #( Freq[k], PCT[k]),
        #
# Out:
# ( 0 , 0 ): [
# ( 0.344444444 , 1 ),
# ( 0.262962963 , 5 ),
# ( 0.406481481 , 6 ),
# ( 0.271296296 , 7 ),
# ( 0.314814815 , 9 ),
# ( 0.332407407 , 10 ),
# ( 0.387962963 , 13 ),
# ( 0.446296296 , 14 ),
# ( 0.237037037 , 17 ),
# ( 0.361111111 , 18 ),
# ( 0.271296296 , 19 ),
# ( 0.327777778 , 20 ),
# ( 0.010185185 , 22 ),
# ( 0.446296296 , 23 ),
# ( 0.413888889 , 24 ),
# ( 0.324074074 , 25 ),
# ( 0.17037037 , 26 ),
# ( 0.262037037 , 28 ),
# ( 0.291666667 , 30 ),
# ( 0.375 , 32 ),
# ( 0.37037037 , 33 ),
# ( 0.776851852 , 34 )],
# ( 0 , 1 ): [
# ( 0.800925926 , 1 ),
# ( 0.437962963 , 5 ),
# ( 0.439814815 , 6 ),
# ( 0.422222222 , 7 ),
# ( 0.425 , 9 ),
# ( 0.427777778 , 10 ),
# ( 0.946296296 , 13 ),
# ( 1.126851852 , 14 ),
# ( 0.387962963 , 17 ),
# ( 0.77037037 , 18 ),
# ( 0.787037037 , 19 ),
# ( 0.537037037 , 20 ),
# ( 0.039814815 , 22 ),
# ( 0.768518519 , 23 ),
# ( 0.606481481 , 24 ),
# ( 0.684259259 , 25 ),
# ( 0.349074074 , 26 ),
# ( 0.501851852 , 28 ),
# ( 0.409259259 , 30 ),
# ...
