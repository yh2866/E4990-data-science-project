# %%
import pandas as pd
df =pd.read_csv('NYPD_Data.csv')
df.head()
# Out:
#    CMPLNT_NUM CMPLNT_FR_DT CMPLNT_FR_TM CMPLNT_TO_DT CMPLNT_TO_TM   RPT_DT  \
# 0   822760976     1983/3/3     21:30:00       3/4/16      4:00:00   3/4/16
# 1   267058046     1986/2/7     21:00:00      6/17/16     13:10:00  4/16/16
# 2   712268575    1987/2/25     12:00:00      2/23/16      9:53:00  2/23/16
# 3   761641495    1987/9/18      0:01:00       2/2/16     14:46:00   2/2/16
# 4   710136073     1991/1/1      6:00:00       1/1/93      6:00:00   4/7/16
#
#    KY_CD      OFNS_DESC  PD_CD  \
# 0    341  PETIT LARCENY  338.0
# 1    104           RAPE  157.0
# 2    109  GRAND LARCENY  424.0
# 3    109  GRAND LARCENY  432.0
# 4    104           RAPE  157.0
#
#                                              PD_DESC  \
# 0                     LARCENY,PETIT FROM BUILDING,UN
# 1                                             RAPE 1
# 2  LARCENY,GRAND BY CREDIT CARD ACCT COMPROMISE-E...
# 3       LARCENY,GRAND BY IDENTITY THEFT-UNCLASSIFIED
# 4                                             RAPE 1
#
#                ...               ADDR_PCT_CD LOC_OF_OCCUR_DESC  \
# 0              ...                        10            INSIDE
# 1              ...                       109            INSIDE
# 2              ...                        62            INSIDE
# 3              ...                        25            INSIDE
# 4              ...                       110            INSIDE
#
#             PREM_TYP_DESC PARKS_NM     HADEVELOPT X_COORD_CD Y_COORD_CD  \
# 0             HOTEL/MOTEL      NaN            NaN   983423.0   209491.0
# 1  RESIDENCE - APT. HOUSE      NaN            NaN  1007115.0   237715.0
# 2  RESIDENCE - APT. HOUSE      NaN  RED HOOK WEST   989266.0   157706.0
# 3  RESIDENCE - APT. HOUSE      NaN            NaN   999588.0   230862.0
# 4         RESIDENCE-HOUSE      NaN            NaN   981530.0   173860.0
#
#     Latitude  Longitude                        Lat_Lon
# 0  40.741689 -74.002986    (40.7416892, -74.002985851)
# 1  40.819127 -73.917392  (40.819127068, -73.917392286)
# 2  40.599550 -73.981939  (40.599549586, -73.981938688)
# 3  40.800334 -73.944602    (40.800333759, -73.9446023)
# 4  40.643890 -74.009803  (40.643889954, -74.009802745)
#
# [5 rows x 24 columns]

# %%
df_=df[['CMPLNT_NUM', 'CMPLNT_FR_DT', 'CMPLNT_FR_TM', 'ADDR_PCT_CD']]
df_.head()
# Out:
#    CMPLNT_NUM CMPLNT_FR_DT CMPLNT_FR_TM  ADDR_PCT_CD
# 0   822760976     1983/3/3     21:30:00           10
# 1   267058046     1986/2/7     21:00:00          109
# 2   712268575    1987/2/25     12:00:00           62
# 3   761641495    1987/9/18      0:01:00           25
# 4   710136073     1991/1/1      6:00:00          110

# %%
#df_['CMPLNT_FR_DT']
df__ = pd.to_datetime(df_['CMPLNT_FR_DT'])
df__.head()
# Out:
# 0   1983-03-03
# 1   1986-02-07
# 2   1987-02-25
# 3   1987-09-18
# 4   1991-01-01
# Name: CMPLNT_FR_DT, dtype: datetime64[ns]

# %%
df_weekdays = df__.dt.dayofweek
df_weekdays.head()
# Out:
# 0    3
# 1    4
# 2    2
# 3    4
# 4    1
# Name: CMPLNT_FR_DT, dtype: int64

# %%
df_['CMPLNT_FR_DT'] = df_weekdays
df_.head()
# Out:
# /Users/hongyuanqing/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
#    CMPLNT_NUM  CMPLNT_FR_DT CMPLNT_FR_TM  ADDR_PCT_CD
# 0   822760976             3     21:30:00           10
# 1   267058046             4     21:00:00          109
# 2   712268575             2     12:00:00           62
# 3   761641495             4      0:01:00           25
# 4   710136073             1      6:00:00          110

# %%
df____ = pd.to_datetime(df_['CMPLNT_FR_TM']).dt.hour
df____.head()
# Out:
# 0    21
# 1    21
# 2    12
# 3     0
# 4     6
# Name: CMPLNT_FR_TM, dtype: int64

# %%
df_['CMPLNT_FR_TM'] = df____
df_.head()
# Out:
# /Users/hongyuanqing/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
#    CMPLNT_NUM  CMPLNT_FR_DT  CMPLNT_FR_TM  ADDR_PCT_CD
# 0   822760976             3            21           10
# 1   267058046             4            21          109
# 2   712268575             2            12           62
# 3   761641495             4             0           25
# 4   710136073             1             6          110

# %%
import numpy as np
#df_.groupby(['CMPLNT_FR_DT', 'CMPLNT_FR_TM']).agg({'df_': [np.size]})

df2 = df_.groupby(['CMPLNT_FR_DT','CMPLNT_FR_TM','ADDR_PCT_CD']).size()
df2
# Out:
# CMPLNT_FR_DT  CMPLNT_FR_TM  ADDR_PCT_CD
# 0             0             1               8
#                             5               5
#                             6              10
#                             7               6
#                             9               5
#                             10              6
#                             13             15
#                             14              9
#                             17             11
#                             18             11
#                             19             10
#                             20              9
#                             22              1
#                             23             11
#                             24             14
#                             25              5
#                             26              2
#                             28              6
#                             30              5
#                             32              6
#                             33              7
#                             34             14
#                             40             19
#                             41             13
#                             42              6
#                             43             22
#                             44             15
#                             45              9
#                             46             10
#                             47             19
#                                            ..
# 6             23            76              7
#                             77              6
#                             78              6
#                             79             14
#                             81             11
#                             83              4
#                             84              3
#                             88              6
#                             90             13
#                             94              5
#                             100             3
#                             101             7
#                             102             9
#                             103             7
#                             104            13
#                             105            13
#                             106            19
#                             107            12
#                             108             3
#                             109            17
#                             110             6
#                             111             4
#                             112             4
#                             113            14
#                             114            16
#                             115            14
#                             120            12
#                             121             6
#                             122             6
#                             123             2
# dtype: int64

# %%
example_pivot_table = pd.pivot_table(df_, values='CMPLNT_NUM', columns=['CMPLNT_FR_DT','CMPLNT_FR_TM','ADDR_PCT_CD'], aggfunc='count')
print example_pivot_table
# Out:
# CMPLNT_FR_DT  CMPLNT_FR_TM  ADDR_PCT_CD
# 0             0             1               8
#                             5               5
#                             6              10
#                             7               6
#                             9               5
#                             10              6
#                             13             15
#                             14              9
#                             17             11
#                             18             11
#                             19             10
#                             20              9
#                             22              1
#                             23             11
#                             24             14
#                             25              5
#                             26              2
#                             28              6
#                             30              5
#                             32              6
#                             33              7
#                             34             14
#                             40             19
#                             41             13
#                             42              6
#                             43             22
#                             44             15
#                             45              9
#                             46             10
#                             47             19
#                                            ..
# 6             23            76              7
#                             77              6
#                             78              6
#                             79             14
#                             81             11
#                             83              4
#                             84              3
#                             88              6
#                             90             13
#                             94              5
#                             100             3
#                             101             7
#                             102             9
#                             103             7
#                             104            13
#                             105            13
#                             106            19
#                             107            12
#                             108             3
#                             109            17
#                             110             6
#                             111             4
#                             112             4
#                             113            14
#                             114            16
#                             115            14
#                             120            12
#                             121             6
#                             122             6
#                             123             2
# dtype: int64

# %%
abc = example_pivot_table.index.get_level_values(2).astype('float')
print abc

# %%
print abc[4]/abc[5]

# %%
example_pivot_table[]

# %%
example_pivot_table['Value']

# %%
abc = example_pivot_table.index.get_level_values(2).astype('float')
print abc

# %%
example_pivot_table['CMPLNT_NUM']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-d783c652c7a7> in <module>()
# ----> 1 example_pivot_table['CMPLNT_NUM']
#
# /Users/hongyuanqing/anaconda/lib/python2.7/site-packages/pandas/core/series.pyc in __getitem__(self, key)
#     581         key = com._apply_if_callable(key, self)
#     582         try:
# --> 583             result = self.index.get_value(self, key)
#     584
#     585             if not lib.isscalar(result):
#
# /Users/hongyuanqing/anaconda/lib/python2.7/site-packages/pandas/indexes/multi.pyc in get_value(self, series, key)
#     624                     raise InvalidIndexError(key)
#     625                 else:
# --> 626                     raise e1
#     627             except Exception:  # pragma: no cover
#     628                 raise e1
#
# KeyError: 'CMPLNT_NUM'

# %%
example_pivot_table.unstack()
# Out:
# ADDR_PCT_CD                 1     5     6     7     9     10    13    14   \
# CMPLNT_FR_DT CMPLNT_FR_TM
# 0            0              8.0   5.0  10.0   6.0   5.0   6.0  15.0   9.0
#              1              7.0   4.0   8.0   4.0   2.0   5.0   5.0   7.0
#              2              2.0   1.0   6.0   3.0   6.0   6.0   2.0   3.0
#              3              4.0   3.0   5.0   2.0   2.0   5.0   2.0   2.0
#              4              5.0   1.0   4.0   5.0   NaN   2.0   1.0   4.0
#              5              2.0   1.0   1.0   NaN   NaN   1.0   1.0   1.0
#              6              5.0   1.0   4.0   1.0   1.0   3.0   2.0   1.0
#              7              5.0   5.0   4.0   2.0   3.0   1.0   3.0   5.0
#              8             11.0   1.0  10.0   5.0   5.0   6.0  14.0  13.0
#              9             13.0   5.0   4.0   9.0   6.0  10.0  14.0  18.0
#              10            12.0  13.0   5.0   5.0   6.0   4.0  17.0  19.0
#              11            10.0   9.0   5.0   5.0   4.0   2.0  10.0  23.0
#              12            25.0  17.0  16.0  13.0  12.0  16.0  26.0  28.0
#              13            10.0  17.0   9.0   2.0   9.0   5.0  14.0  25.0
#              14            24.0  11.0   4.0   9.0   3.0   6.0  17.0  30.0
#              15            17.0  26.0   9.0  15.0   9.0   9.0  18.0  26.0
#              16            16.0  10.0   4.0   7.0  11.0   9.0  13.0  29.0
#              17            18.0  23.0  12.0  13.0  12.0   5.0  20.0  31.0
#              18            12.0   4.0  13.0  10.0  11.0   9.0  14.0  28.0
#              19             8.0  15.0   8.0   6.0   6.0   3.0  14.0  29.0
#              20            10.0   1.0   7.0   7.0  12.0   1.0   8.0  17.0
#              21             3.0   2.0   5.0   1.0   9.0   3.0   8.0   8.0
#              22             6.0   5.0   3.0   NaN   2.0   5.0   8.0   6.0
#              23             5.0   2.0   3.0   1.0   6.0   5.0   7.0   8.0
# 1            0              6.0  14.0   2.0   4.0   8.0   1.0  14.0   8.0
#              1              2.0   4.0   1.0   3.0   5.0   4.0   3.0   5.0
#              2              1.0   1.0   3.0   NaN   4.0   1.0   5.0   6.0
#              3              NaN   4.0   3.0   2.0   6.0   2.0   3.0   2.0
#              4              1.0   NaN   4.0   1.0   3.0   5.0   4.0   6.0
#              5              6.0   NaN   1.0   NaN   NaN   1.0   1.0   1.0
# ...                         ...   ...   ...   ...   ...   ...   ...   ...
# 5            18            16.0   7.0   9.0   8.0  10.0   9.0  17.0  29.0
#              19            10.0  12.0   8.0  11.0   6.0  10.0  12.0  27.0
#              20             9.0   2.0  14.0   6.0   8.0   7.0  18.0  31.0
#              21             2.0  10.0   6.0   6.0  21.0   4.0   6.0  18.0
#              22             2.0   5.0   7.0   7.0   5.0   8.0   7.0  13.0
#              23             8.0   3.0  11.0  13.0  17.0   9.0   8.0  16.0
# 6            0              9.0   3.0  10.0   9.0  16.0   3.0  14.0  14.0
#              1              7.0  14.0  24.0  19.0  19.0  10.0  12.0  11.0
#              2              9.0   9.0  18.0  10.0  26.0  15.0   8.0  13.0
#              3              5.0   7.0  15.0  10.0  11.0  11.0  15.0   4.0
#              4              6.0   4.0  14.0  10.0  11.0   9.0  10.0  11.0
#              5              1.0   2.0   2.0   2.0   2.0   6.0   2.0   6.0
#              6              3.0   1.0   4.0   1.0   3.0   NaN   9.0   7.0
#              7              1.0   NaN   1.0   5.0   2.0   NaN   4.0   5.0
#              8              3.0   1.0   1.0   1.0   2.0   4.0   1.0   6.0
#              9              6.0   4.0   2.0   3.0   4.0   4.0   2.0   7.0
#              10             5.0   4.0   5.0   4.0   8.0   3.0   8.0  10.0
#              11             5.0   6.0   4.0   3.0   4.0   5.0   7.0  15.0
#              12            17.0   2.0  10.0   7.0   7.0   7.0   9.0  17.0
#              13             9.0   4.0   5.0   2.0   6.0   1.0   7.0  26.0
#              14            13.0   9.0   4.0   5.0  10.0   1.0  11.0  22.0
#              15            11.0   9.0   6.0   8.0  11.0   8.0   7.0  22.0
#              16            12.0   8.0   9.0  10.0  16.0   7.0  12.0  27.0
#              17            11.0   9.0  12.0   9.0  12.0   6.0  11.0  29.0
#              18            16.0   7.0  11.0  14.0   6.0  10.0  18.0  23.0
#              19            12.0   4.0   5.0   5.0  10.0   3.0  10.0  26.0
#              20             6.0   2.0   9.0   5.0   6.0   1.0   8.0   5.0
#              21             5.0   8.0   7.0   3.0   7.0   3.0   5.0  10.0
#              22             4.0   7.0   4.0   7.0   3.0   5.0  10.0   9.0
#              23             3.0   3.0   6.0   8.0  10.0   5.0   6.0  18.0
#
# ADDR_PCT_CD                 17    18   ...    110   111   112   113   114  \
# CMPLNT_FR_DT CMPLNT_FR_TM              ...
# 0            0             11.0  11.0  ...    7.0   3.0   8.0   7.0  25.0
#              1              3.0   6.0  ...    5.0   4.0   8.0   5.0   5.0
#              2              1.0   NaN  ...    4.0   4.0   3.0   4.0   8.0
#              3              NaN   1.0  ...    6.0   2.0   3.0   7.0   3.0
#              4              1.0   4.0  ...    6.0   2.0   NaN  11.0   9.0
#              5              NaN   NaN  ...    4.0   NaN   NaN   3.0   3.0
#              6              1.0   4.0  ...    4.0   1.0   2.0   3.0   6.0
#              7              1.0   9.0  ...    6.0   4.0   4.0  11.0   8.0
#              8              3.0  10.0  ...    6.0   3.0   5.0  21.0  11.0
#              9              6.0  10.0  ...    5.0   8.0   7.0  12.0  17.0
#              10             6.0  12.0  ...    9.0   4.0   6.0  18.0  16.0
#              11             5.0   6.0  ...    9.0   3.0   7.0  15.0  11.0
#              12            15.0  12.0  ...   13.0  16.0   6.0  16.0  34.0
#              13             3.0  15.0  ...   14.0   5.0  11.0  12.0  10.0
#              14             5.0  24.0  ...   11.0   7.0   5.0  18.0  13.0
#              15            16.0  22.0  ...   17.0   4.0   6.0  15.0  16.0
#              16             9.0  25.0  ...   23.0   5.0   6.0  19.0  17.0
#              17            11.0  21.0  ...   19.0   3.0  13.0  14.0  13.0
#              18             4.0  18.0  ...   15.0   6.0   9.0  12.0  11.0
#              19             7.0  17.0  ...   13.0   4.0   7.0  12.0  12.0
#              20            11.0  11.0  ...   16.0   5.0  11.0  30.0  26.0
#              21             6.0   5.0  ...   14.0   9.0   5.0  14.0  12.0
#              22             6.0   5.0  ...    5.0   4.0   2.0  17.0  13.0
#              23             2.0   8.0  ...   12.0   3.0   3.0  13.0  15.0
# 1            0              8.0   7.0  ...    5.0  13.0   2.0  12.0  20.0
#              1              1.0   2.0  ...    7.0   5.0   4.0   8.0   5.0
#              2              3.0   5.0  ...    4.0   4.0   4.0   4.0   9.0
#              3              2.0   6.0  ...    5.0   1.0   1.0   2.0   6.0
#              4              4.0   6.0  ...    7.0   NaN   1.0   5.0   2.0
#              5              NaN   1.0  ...    1.0   NaN   2.0   3.0   2.0
# ...                         ...   ...  ...    ...   ...   ...   ...   ...
# 5            18             6.0  19.0  ...   24.0   6.0   8.0  16.0  28.0
#              19             7.0  23.0  ...   13.0   4.0  10.0  16.0  15.0
#              20             3.0  13.0  ...   16.0   8.0   4.0  15.0  18.0
#              21            10.0  20.0  ...   18.0   2.0   3.0  16.0  11.0
#              22             2.0  16.0  ...    8.0   3.0   4.0  11.0  17.0
#              23             5.0  13.0  ...   16.0   8.0   3.0  19.0  13.0
# 6            0              8.0  14.0  ...   11.0   9.0   1.0  13.0  18.0
#              1              1.0  24.0  ...    6.0   8.0   5.0  11.0  21.0
#              2              5.0  21.0  ...   11.0   6.0   3.0  13.0  14.0
#              3              5.0  18.0  ...   17.0   2.0   4.0  12.0  16.0
#              4              5.0  17.0  ...   14.0   NaN   2.0  13.0  21.0
#              5              5.0   9.0  ...    6.0   2.0   3.0   6.0  13.0
#              6              6.0   2.0  ...    4.0   1.0   3.0   2.0  11.0
#              7              3.0   3.0  ...    7.0   1.0   NaN   3.0   5.0
#              8              5.0   3.0  ...    2.0   4.0   NaN   6.0   8.0
#              9              6.0   7.0  ...    3.0   3.0   NaN   9.0   6.0
#              10             2.0   7.0  ...    7.0   4.0   4.0  12.0  12.0
#              11             1.0  12.0  ...    5.0   7.0   3.0   8.0   7.0
#              12            14.0   8.0  ...   19.0  10.0  10.0  16.0  19.0
#              13             3.0  11.0  ...   13.0   4.0   5.0   7.0   8.0
#              14             8.0  11.0  ...   11.0   5.0   6.0  16.0  18.0
#              15             4.0  11.0  ...   16.0   4.0   7.0  12.0  17.0
#              16             7.0  22.0  ...   13.0   9.0  10.0   7.0  17.0
#              17             7.0  18.0  ...   13.0   6.0  10.0  10.0  20.0
#              18             9.0  12.0  ...   16.0   7.0  11.0  15.0  21.0
#              19             2.0  12.0  ...   13.0   8.0   9.0  18.0  12.0
#              20             6.0   6.0  ...   10.0   5.0   6.0  19.0  20.0
#              21             2.0  11.0  ...   10.0   7.0   4.0  14.0  11.0
#              22             4.0   8.0  ...   13.0   5.0   5.0   5.0  14.0
#              23             5.0   7.0  ...    6.0   4.0   4.0  14.0  16.0
#
# ADDR_PCT_CD                 115   120   121   122   123
# CMPLNT_FR_DT CMPLNT_FR_TM
# 0            0             31.0  18.0   9.0   7.0   3.0
#              1              6.0   8.0  10.0   6.0   3.0
#              2              8.0   5.0  10.0   5.0   NaN
#              3             11.0   9.0   1.0   6.0   1.0
#              4             11.0   7.0   5.0   3.0   1.0
#              5              5.0   3.0   2.0   NaN   NaN
#              6             12.0   7.0   5.0   3.0   3.0
#              7              9.0  10.0   4.0   4.0   1.0
#              8             12.0  15.0   9.0   8.0   6.0
#              9             12.0  11.0  10.0  11.0   2.0
#              10             8.0  15.0  14.0  10.0   3.0
#              11             9.0   7.0  13.0   6.0   8.0
#              12            14.0  16.0  18.0  24.0   5.0
#              13            11.0   9.0  12.0  13.0   8.0
#              14            18.0  18.0  19.0   9.0   3.0
#              15            13.0  12.0  14.0  13.0   7.0
#              16            11.0  10.0  12.0  11.0   5.0
#              17             6.0  17.0  19.0  10.0   4.0
#              18            10.0   9.0  19.0  11.0  10.0
#              19            13.0  16.0  16.0  11.0   2.0
#              20            13.0  22.0  16.0  17.0   8.0
#              21            11.0   5.0  12.0  10.0   3.0
#              22            10.0  13.0  10.0  12.0   9.0
#              23             7.0  10.0   5.0   8.0   1.0
# 1            0             12.0  14.0  12.0   8.0   3.0
#              1              5.0   5.0   3.0   6.0   3.0
#              2              4.0   5.0   6.0   7.0   NaN
#              3              2.0   8.0   2.0   2.0   NaN
#              4              7.0   5.0   3.0   2.0   NaN
#              5              5.0   3.0   5.0   1.0   1.0
# ...                         ...   ...   ...   ...   ...
# 5            18             8.0  18.0  23.0   7.0   3.0
#              19            18.0  15.0   9.0  15.0   6.0
#              20            16.0  26.0  14.0   9.0   3.0
#              21            19.0  12.0  18.0  10.0   4.0
#              22            14.0  22.0  16.0   7.0  12.0
#              23            14.0   9.0  19.0   6.0   4.0
# 6            0             18.0  15.0  12.0   3.0   6.0
#              1             16.0  13.0   9.0   6.0   7.0
#              2             16.0  11.0   8.0   7.0   5.0
#              3             24.0  11.0  14.0   4.0   4.0
#              4             33.0   7.0  10.0   5.0   3.0
#              5             11.0   5.0   4.0   1.0   2.0
#              6             11.0   2.0   1.0   2.0   1.0
#              7              4.0   5.0   2.0   1.0   NaN
#              8              4.0   5.0   2.0   5.0   2.0
#              9             16.0  10.0   9.0   3.0   4.0
#              10             4.0  10.0  12.0   7.0   7.0
#              11            10.0   6.0   5.0  10.0   3.0
#              12            12.0  15.0  14.0   8.0  14.0
#              13            19.0  19.0   9.0  13.0   4.0
#              14             6.0  16.0  11.0  12.0   1.0
#              15            11.0  16.0  14.0  16.0   5.0
#              16            15.0  12.0  14.0  13.0   3.0
#              17            11.0  13.0  11.0   9.0   7.0
#              18            12.0  19.0  12.0  14.0   3.0
#              19            12.0  12.0   7.0   3.0   3.0
#              20            14.0  11.0  12.0  10.0   3.0
#              21            13.0  10.0   8.0   4.0   6.0
#              22             9.0  15.0   7.0  13.0   8.0
#              23            14.0  12.0   6.0   6.0   2.0
#
# [168 rows x 77 columns]

# %%
example_pivot_table.pivot_table(columns='CMPLNT_NUM')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-6dfd3860dfae> in <module>()
# ----> 1 example_pivot_table.pivot_table(columns='CMPLNT_NUM')
#
# /Users/hongyuanqing/anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in __getattr__(self, name)
#    2670             if name in self._info_axis:
#    2671                 return self[name]
# -> 2672             return object.__getattribute__(self, name)
#    2673
#    2674     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'pivot_table'

# %%
print dir()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-b515db4bd0d4> in <module>()
# ----> 1 print dir(privot)
#
# NameError: name 'privot' is not defined

# %%
example_pivot_table.values
# Out:
# array([ 8,  5, 10, ...,  6,  6,  2])
